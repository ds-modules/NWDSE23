# %%
import pandas as pd

# %% [markdown]
# # 1 - Nenana Ice Classic Data
# ## Need to login and download the data - manage the csv file
#
# Had to create a profile at
# https://urs.earthdata.nasa.gov/profile
#
# https://daacdata.apps.nsidc.org/pub/DATASETS/nsidc0064_nenana_ice_classic_v2/NenanaIceClassic_1917-2021.csv

# %%
#upload to Jupyterhub
ice_df = pd.read_csv("NenanaIceClassic_1917-2021.csv")
ice_df
# Out:
#      Year  Decimal Day of Year  Month  Day   Time
# 0    1917             120.4792  April   30  11:30
# 1    1918             131.3979    May   11  09:33
# 2    1919             123.6063    May    3  14:33
# 3    1920             132.4486    May   11  10:46
# 4    1921             131.2792    May   11  06:42
# ..    ...                  ...    ...  ...    ...
# 100  2017             121.5000    May    1  12:00
# 101  2018             121.5542    May    1  13:18
# 102  2019             104.0146  April   14  00:21
# 103  2020             118.5389  April   27  12:56
# 104  2021             120.5347  April   30  12:50
#
# [105 rows x 5 columns]

# %% [markdown]
# # 2- Getting Datasets from DSSJ datasets repository
# https://sites.google.com/view/dssj/projects
#
# For Example
# ## CSV for Florida Covid dataset
# https://figshare.com/articles/dataset/COVID-19/14552367?file=28042047

# %%
# !wget https://figshare.com/ndownloader/files/28042047
# Out:
# --2023-07-18 10:43:32--  https://figshare.com/ndownloader/files/28042047
# Resolving figshare.com (figshare.com)... 34.242.105.80, 34.250.148.102, 2a05:d018:1f4:d000:2df1:b4d4:f8bf:d1c, ...
# Connecting to figshare.com (figshare.com)|34.242.105.80|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/28042047/CoViDCasesFL.csv?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20230718/eu-west-1/s3/aws4_request&X-Amz-Date=20230718T174333Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=742946b2ca01ba9739661e8a7a3987dc2a12db2d19e8a2217f20cda29923214b [following]
# ...

# %%
# !ls
# Out:
# 28042047      ES-21AC-SP21-key		      NenanaIceClassic_1917-2021.csv.1
# covid_fl.csv  ICERM_DataImports.ipynb
# EEP-147-SP23  NenanaIceClassic_1917-2021.csv

# %%
# !mv 28042047 covid_fl.csv

# %%
covid_fl_df = pd.read_csv("covid_fl.csv")
covid_fl_df
# Out:
#      FIPS      County Province_State Country_Region          Last_Update  \
# 0   12001     Alachua        Florida             US  2021-05-17 04:20:34
# 1   12003       Baker        Florida             US  2021-05-17 04:20:34
# 2   12005         Bay        Florida             US  2021-05-17 04:20:34
# 3   12007    Bradford        Florida             US  2021-05-17 04:20:34
# 4   12009     Brevard        Florida             US  2021-05-17 04:20:34
# ..    ...         ...            ...            ...                  ...
# 63  12125       Union        Florida             US  2021-05-17 04:20:34
# 64  12127     Volusia        Florida             US  2021-05-17 04:20:34
# 65  12129     Wakulla        Florida             US  2021-05-17 04:20:34
# 66  12131      Walton        Florida             US  2021-05-17 04:20:34
# 67  12133  Washington        Florida             US  2021-05-17 04:20:34
#
#      Latitude  Longitude  Confirmed  Deaths  Recovered  Active  \
# ...

# %% [markdown]
# ## 3 - Book Chapter - Quantititative Research 4 Social Justice
#
# https://github.com/Zibiana/QR4SJ/blob/main/remixed-sections/Data_Files/State-payday-loan-rates-03-21-only-predatory.xlsx

# %%
#upload to Jupyterhub
# !ls
# Out:
# covid_fl.csv	  ICERM_DataImports.ipynb
# crdc.zip	  NenanaIceClassic_1917-2021.csv
# EEP-147-SP23	  Poverty-School-ussd21.xls
# ES-21AC-SP21-key  State-payday-loan-rates-03-21-only-predatory.xlsx

# %%
payday_df = pd.read_excel("State-payday-loan-rates-03-21-only-predatory.xlsx")
payday_df
# Out:
#              State  Typical Payday Loan APR
# 0             Ohio                     1.38
# 1           Oregon                     1.54
# 2         Virginia                     1.73
# 3       New Mexico                     1.75
# 4        Minnesota                     2.00
# 5         Oklahoma                     2.03
# 6            Maine                     2.17
# 7     Rhode Island                     2.61
# 8          Wyoming                     2.61
# 9          Florida                     3.04
# 10            Iowa                     3.36
# 11        Michigan                     3.70
# 12         Indiana                     3.82
# 13        Delaware                     3.91
# 14          Kansas                     3.91
# 15      Washington                     3.91
# 16  South Carolina                     3.95
# 17          Alaska                     4.35
# 18         Alabama                     4.56
# 19      California                     4.60
# ...
